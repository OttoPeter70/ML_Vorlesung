# %%
import pandas as pd
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('College.csv')
df
# Out:
#                          Unnamed: 0 Private   Apps  Accept  Enroll  Top10perc  \
# 0      Abilene Christian University     Yes   1660    1232     721         23
# 1                Adelphi University     Yes   2186    1924     512         16
# 2                    Adrian College     Yes   1428    1097     336         22
# 3               Agnes Scott College     Yes    417     349     137         60
# 4         Alaska Pacific University     Yes    193     146      55         16
# ..                              ...     ...    ...     ...     ...        ...
# 772         Worcester State College      No   2197    1515     543          4
# 773               Xavier University     Yes   1959    1805     695         24
# 774  Xavier University of Louisiana     Yes   2097    1915     695         34
# 775                 Yale University     Yes  10705    2453    1317         95
# 776    York College of Pennsylvania     Yes   2989    1855     691         28
#
# ...

# %% [markdown]
# Ein Dataframe ist eine Datenstruktur die ähnlich wie ein Excel File/eine relationale DB ist.

# %%
df.describe()
# Out:
#                Apps        Accept       Enroll   Top10perc   Top25perc  \
# count    777.000000    777.000000   777.000000  777.000000  777.000000
# mean    3001.638353   2018.804376   779.972973   27.558559   55.796654
# std     3870.201484   2451.113971   929.176190   17.640364   19.804778
# min       81.000000     72.000000    35.000000    1.000000    9.000000
# 25%      776.000000    604.000000   242.000000   15.000000   41.000000
# 50%     1558.000000   1110.000000   434.000000   23.000000   54.000000
# 75%     3624.000000   2424.000000   902.000000   35.000000   69.000000
# max    48094.000000  26330.000000  6392.000000   96.000000  100.000000
#
#         F.Undergrad   P.Undergrad      Outstate   Room.Board        Books  \
# count    777.000000    777.000000    777.000000   777.000000   777.000000
# mean    3699.907336    855.298584  10440.669241  4357.526384   549.380952
# std     4850.420531   1522.431887   4023.016484  1096.696416   165.105360
# ...

# %% [markdown]
# count: Anzahl Einträge, mean: mean, std:..., min:Minimum, 25,50,75: Quantile, max:Maximum

# %%
df2 = df.iloc[:, : 10]

# %%
scatter_matrix(df2)
# Out:
# array([[<Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Accept', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>,
#         <Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Top25perc', ylabel='Apps'>,
#         <Axes: xlabel='F.Undergrad', ylabel='Apps'>,
#         <Axes: xlabel='P.Undergrad', ylabel='Apps'>,
#         <Axes: xlabel='Outstate', ylabel='Apps'>],
#        [<Axes: xlabel='Apps', ylabel='Accept'>,
#         <Axes: xlabel='Accept', ylabel='Accept'>,
#         <Axes: xlabel='Enroll', ylabel='Accept'>,
#         <Axes: xlabel='Top10perc', ylabel='Accept'>,
#         <Axes: xlabel='Top25perc', ylabel='Accept'>,
#         <Axes: xlabel='F.Undergrad', ylabel='Accept'>,
#         <Axes: xlabel='P.Undergrad', ylabel='Accept'>,
#         <Axes: xlabel='Outstate', ylabel='Accept'>],
#        [<Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Accept', ylabel='Enroll'>,
# ...

# %%
scatter_matrix(df2,figsize=(15,15), s=50, marker='D')
# Out:
# array([[<Axes: xlabel='Apps', ylabel='Apps'>,
#         <Axes: xlabel='Accept', ylabel='Apps'>,
#         <Axes: xlabel='Enroll', ylabel='Apps'>,
#         <Axes: xlabel='Top10perc', ylabel='Apps'>,
#         <Axes: xlabel='Top25perc', ylabel='Apps'>,
#         <Axes: xlabel='F.Undergrad', ylabel='Apps'>,
#         <Axes: xlabel='P.Undergrad', ylabel='Apps'>,
#         <Axes: xlabel='Outstate', ylabel='Apps'>],
#        [<Axes: xlabel='Apps', ylabel='Accept'>,
#         <Axes: xlabel='Accept', ylabel='Accept'>,
#         <Axes: xlabel='Enroll', ylabel='Accept'>,
#         <Axes: xlabel='Top10perc', ylabel='Accept'>,
#         <Axes: xlabel='Top25perc', ylabel='Accept'>,
#         <Axes: xlabel='F.Undergrad', ylabel='Accept'>,
#         <Axes: xlabel='P.Undergrad', ylabel='Accept'>,
#         <Axes: xlabel='Outstate', ylabel='Accept'>],
#        [<Axes: xlabel='Apps', ylabel='Enroll'>,
#         <Axes: xlabel='Accept', ylabel='Enroll'>,
# ...

# %% [markdown]
# Scatter Matrix erstellt für jede Column mit jeder anderen Column einen Scatter Plot.

# %%
ax1 = plt.subplot()
ax1.set_title('Boxplot Outstate')
ax1.boxplot(df['Outstate'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x265fb39b1f0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x26591550310>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2658f77b8e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x26591550730>],
#  'fliers': [<matplotlib.lines.Line2D at 0x265915509d0>],
#  'means': []}

# %% [markdown]
# Im Median kommen ca 10.000 Studenten von außerhalb des Staates der Uni. Das obere Quartil endet bei ca 12.500, das untere bei 7500. Ein Outlier nach oben mit ca 22.000 Studenten existiert.

# %%
sns.countplot(x = df['Private'])
# Out:
# <Axes: xlabel='Private', ylabel='count'>

# %%
df['Elite'] = np.where(df['Top10perc'] > 50, True, False)

# %%
sns.countplot(x = df['Elite'])
# Out:
# <Axes: xlabel='Elite', ylabel='count'>

# %% [markdown]
# 0 Elitehochschulen
